# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Activation
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from sklearn import datasets

# %%
n_class = 3
x,y = datasets.make_classification(n_samples=200,n_features=2,n_informative=2,n_redundant=0,n_repeated=0,n_classes=n_class,n_clusters_per_class=1)

# %%
y = np_utils.to_categorical(y,n_class)

# %%
model = Sequential()
model.add(Dense(n_class,input_dim=2))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy",optimizer="sgd",metrics=['accuracy'])

# %%
hist = model.fit(x,y,epochs=2000,verbose=0)

# %%
plt.scatter(range(len(hist.history['loss'])),hist.history['loss'])

# %%
w,b = model.layers[0].get_weights()
print(w,b)
# Out:
# [[ 3.3225102   0.02071185 -2.4229102 ]
#  [ 1.941345    0.84816    -2.9073555 ]] [ 0.31549314  0.9771555  -1.2926481 ]

# %%
y_pred = model.predict(x)
y_pred = y_pred.argmax(axis=1)

# %%
plt.subplot(2,1,1).scatter(x[:,0],x[:,1],c=y_pred)
plt.subplot(2,1,2).scatter(x[:,0],x[:,1],c=y)

# %%
plt.scatter(x[:,0],x[:,1],c=y)
y00 = np.linspace(-4,2,10)*w[0,0]+b[0]
y01 = np.linspace(-4,2,10)*w[1,0]+b[0]
y10 = np.linspace(-4,2,10)*w[0,1]+b[1]
y11 = np.linspace(-4,2,10)*w[1,1]+b[1]
y20 = np.linspace(-4,2,10)*w[0,2]+b[2]
y21 = np.linspace(-4,2,10)*w[1,2]+b[2]
plt.plot(np.linspace(-2,4,10),y00,'m',linewidth=2)
plt.plot(np.linspace(-2,4,10),y01,'m',linewidth=2)
plt.plot(np.linspace(-2,4,10),y10,'m',linewidth=2)
plt.plot(np.linspace(-2,4,10),y11,'m',linewidth=2)
plt.plot(np.linspace(-2,4,10),y20,'m',linewidth=2)
plt.plot(np.linspace(-2,4,10),y21,'m',linewidth=2)
